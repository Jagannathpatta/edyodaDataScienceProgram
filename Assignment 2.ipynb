# %% [markdown]
# Implement a Bike Rental System with following features.
#
# Customers
#
#     1. See available bikes on the shop.
#     2. Rent bikes on hourly basis $5 per hour.
#     3. Rent bikes on daily basis $20 per day.
#     4. Rent bikes on weekly basis $60 per week.
#     5. Group Rental, a promotion that can include from 3 to 5 Rentals (of any type) with a discount of 30% of the total price
#
# Rental shops
#
#     1. Issue a bill when customer decides to return the bike.
#     2. Display available inventory
#     3. Take requests on hourly, daily and weekly basis by cross verifying stock

# %%
class Customers:
    
    customers = []
    count = 0
    @classmethod
    def add_customer(cls, obj):
        cls.customers.append(obj)
        
    def __init__(self , name , email , phone , DRlicenceNo , address):
        self.cust_id = lec(Customers.customers) + 1 + count
        self.name = name
        self.email = email
        self.phone = phone
        self.DRlicenceNo = DRlicenceNo
        self.address = address
        Customers.customers.append(self)
    
    def view_available_bikes(self):
        l = []
        for i in Bikes.bikes:
            if i.status == 0:
                l.append(i.__dict__)
        return l
                
    
    def rental_rates(self):
        print("$5 per Hour")
        print("$20 per Day")
        print("$60 per Week")

        
class Booking:
    
    bookings = []
    count = 0
    
    def book_request(self ,bikeID, model , num , issue_date_time , return_date_time , obj):
        self.book_id = len(Booking.bookings) + 1 + Booking.count
        self.bike_id = bikeID
        self.model = model
        self.num = num
        self.issue_date = issue_date_time.date
        self.return_date = return_date_time.date
        self.issue_time = issue_date_time.time
        self.return_time = return_date_time.time
        self.req_status = 0
        self.cust = obj
        Booking.bookings.append(self)
        
        
    
class Bikes:
    
    bikes = []
    count = 0
    @classmethod
    def add_bike(cls, obj):
        cls.bikes.append(obj)
        
    def __init__(self , model , num , mailage ,status ):
        self.id = len(Bikes.bikes) + 1 +Bikes.count
        self.model = model
        self.num = num
        self.mailage = mailage
        self.status = status
        Bikes.add_bike(self)
        
b1 = Bikes(1,"p220" ,"MH04SC1951" , 50 ,0 )
b2 = Bikes(2,"p150" ,"MH02CD1990" , 35 ,0 )
b3 = Bikes(3,"p100" ,"MH01CB1999" , 70 ,0 )
b4 = Bikes(4,"y150" ,"MH06AC1115" , 60 ,0 )
# print(Bikes.bikes)   

class Shop:
        
    
    def view_all_bikes(self):
        l = []
        for i in Bikes.bikes:
            l.append(i.__dict__)
        return l
    
    def calc_bill(self):
        pass
    
    def approve_bookings(self):
        l = []
        for i in Booking.bookings:
            l.append(i.__dict__)
            print(i.__dict__)
        id = int(input("Please Enter the Booking ID from the above mensioned bookingd : "))
        c = int(input(" Press 1 to approve the request And 2 to reject the request : "))
        if c == 1:
            for i in Booking.bookings:
                if i.book_id == id:
                    i.req_status = 1
# Out:
# [<__main__.Bikes object at 0x062FA6F0>, <__main__.Bikes object at 0x062FAA30>, <__main__.Bikes object at 0x062FAA70>, <__main__.Bikes object at 0x062FAF70>]
